# %%
pip install polars
# Out:
# ...
#
#   Obtaining dependency information for polars from https://files.pythonhosted.org/packages/f6/c6/36a1b874036b49893ecae0ac44a2f63d1a76e6212631a5b2f50a86e0e8af/polars-1.36.1-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for polars-runtime-32==1.36.1 from https://files.pythonhosted.org/packages/05/0f/e629713a72999939b7b4bfdbf030a32794db588b04fdf3dc977dd8ea6c53/polars_runtime_32-1.36.1-cp39-abi3-win_amd64.whl.metadata
# ...
#    ---------------------------------------- 0.0/802.4 kB ? eta -:--:--
#    ---------------------------------------- 0.0/802.4 kB ? eta -:--:--
#     --------------------------------------- 10.2/802.4 kB ? eta -:--:--
#    - ------------------------------------- 30.7/802.4 kB 435.7 kB/s eta 0:00:02
#    -- ------------------------------------ 61.4/802.4 kB 544.7 kB/s eta 0:00:02
#    ----- -------------------------------- 112.6/802.4 kB 595.3 kB/s eta 0:00:02
#    ----- -------------------------------- 122.9/802.4 kB 554.9 kB/s eta 0:00:02
# ...

# %%
import polars as ps
import matplotlib.pyplot as plt
